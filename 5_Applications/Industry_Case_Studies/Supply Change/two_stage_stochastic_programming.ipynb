# %% [markdown]
# # Production Planning with Two-Stage Stochastic Programming
#
# ## Problem Statement
#
# This code solves a production planning problem under demand uncertainty using a two-stage stochastic programming approach. In this problem:
#
# 1. A manufacturer must decide how much of a product to produce **before** knowing the actual demand (first-stage decision).
# 2. After the demand is revealed, the manufacturer must decide how much to sell, how much to store, and how much shortage to incur (second-stage decisions).
# 3. The goal is to minimize the total expected cost across all possible demand scenarios.
#
# ## Required Components
#
# ### Libraries
# - **NumPy**: For random number generation and array operations
# - **Pyomo**: For mathematical optimization modeling
# - **GLPK**: The solver used to solve the linear programming model (must be installed separately)
#
# ### Problem Parameters
# 1. **Production Cost**: $10 per unit
# 2. **Storage Cost**: $2 per unit
# 3. **Shortage Cost**: $20 per unit (penalty for not meeting demand)
# 4. **Selling Price**: $15 per unit
# 5. **Base Demand**: 100 units
# 6. **Demand Uncertainty**: Normally distributed with mean 0 and standard deviation 20
#
# ## Code Walkthrough
#
# ### Random Scenario Generation
# ```python
# # Generate random demand scenarios
# base_demand = 100
# demand_scenarios = base_demand + np.random.normal(0, 20, num_scenarios)
# scenario_probs = np.ones(num_scenarios) / num_scenarios  # Equal probability
# ```
#
# This code generates `num_scenarios` different potential demand values. Each scenario represents a possible future demand realization. The demands follow a normal distribution with mean 100 and standard deviation 20. Each scenario is assigned equal probability.
#
# ### Model Structure
#
# #### Decision Variables
# ```python
# # First stage decision variable: how much to produce
# model.produce = pyo.Var(domain=pyo.NonNegativeReals)
#
# # Second stage variables - for each scenario
# model.scenarios = pyo.RangeSet(0, num_scenarios-1)
# model.sell = pyo.Var(model.scenarios, domain=pyo.NonNegativeReals)
# model.store = pyo.Var(model.scenarios, domain=pyo.NonNegativeReals)
# model.shortage = pyo.Var(model.scenarios, domain=pyo.NonNegativeReals)
# ```
#
# - **First Stage**: `model.produce` (before knowing demand)
# - **Second Stage** (for each scenario):
#   - `model.sell[s]`: Amount to sell in scenario s
#   - `model.store[s]`: Amount to store in scenario s
#   - `model.shortage[s]`: Amount of unmet demand in scenario s
#
# #### Objective Function
# ```python
# # First stage objective: minimize production cost
# model.first_stage_cost = pyo.Expression(expr=production_cost * model.produce)
#
# # Second stage objective: expected profit/cost across all scenarios
# def second_stage_rule(model, s):
#     return (scenario_probs[s] *
#             (selling_price * model.sell[s] -
#              storage_cost * model.store[s] -
#              shortage_cost * model.shortage[s]))
#
# model.second_stage_obj = pyo.Expression(model.scenarios, rule=second_stage_rule)
#
# # Total objective: first stage cost + expected second stage cost
# model.obj = pyo.Objective(
#     expr=model.first_stage_cost - sum(model.second_stage_obj[s] for s in model.scenarios),
#     sense=pyo.minimize
# )
# ```
#
# The objective combines:
# 1. **First-stage cost**: Production cost of units made
# 2. **Expected second-stage cost**: Weighted average of revenue minus costs across all scenarios
#    - Revenue from selling units
#    - Minus storage costs for unsold units
#    - Minus shortage penalties for unmet demand
#
# #### Constraints
# ```python
# # For each scenario, amount sold + stored equals amount produced
# def balance_rule(model, s):
#     return model.sell[s] + model.store[s] == model.produce
#
# model.balance = pyo.Constraint(model.scenarios, rule=balance_rule)
#
# # For each scenario, amount sold + shortage equals demand
# def demand_rule(model, s):
#     return model.sell[s] + model.shortage[s] == demand_scenarios[s]
#
# model.demand = pyo.Constraint(model.scenarios, rule=demand_rule)
# ```
#
# Two key constraints:
# 1. **Balance constraint**: The sum of units sold and stored must equal the total produced
# 2. **Demand constraint**: The sum of units sold and shortage must equal the demand
#
# ## Results Interpretation
#
# The function returns a dictionary with:
# - `optimal_production`: The optimal amount to produce (first-stage decision)
# - `expected_cost`: The expected total cost
# - `scenarios`: For each scenario, shows:
#   - The realized demand
#   - How much to sell
#   - How much to store
#   - How much demand goes unfulfilled (shortage)
#
# ## Key Insights
#
# 1. **Making decisions under uncertainty**: This model helps determine the optimal production quantity without knowing the exact demand.
#
# 2. **Hedging against uncertainty**: By considering multiple demand scenarios with their probabilities, the model finds a production amount that minimizes expected costs.
#
# 3. **Risk management**: The model balances the risks of:
#    - Overproduction (which leads to storage costs)
#    - Underproduction (which leads to shortage penalties)
#
# 4. **Value of stochastic solution**: The benefit of using this approach over a deterministic model that uses only the average demand is that it accounts for the asymmetric costs of overproduction versus underproduction.
#
# ## Running the Code
#
# To run this code, you need:
# 1. Python installed with NumPy
# 2. Pyomo package installed
# 3. GLPK solver installed and accessible
# 4. Call the function with desired number of scenarios:
#    ```python
#    results = solve_two_stage_stochastic_program(num_scenarios=10)
#    print(f"Optimal production: {results['optimal_production']}")
#    ```

# %%
import numpy as np
import pyomo.environ as pyo
from pyomo.opt import SolverFactory
import os
import sys

# Function to find the GLPK executable
def find_glpk_executable():
    """
    Find the GLPK executable path on the system.
    Returns the path if found, None otherwise.
    """
    # Potential paths for macOS
    potential_paths = [
        os.path.join(os.environ.get('CONDA_PREFIX', ''), 'bin', 'glpsol'),  # Conda path
        "/opt/homebrew/bin/glpsol",  # Homebrew on Apple Silicon
        "/usr/local/bin/glpsol",     # Homebrew on Intel Macs
        # Add Windows paths if needed
        "C:\\glpk\\w64\\glpsol.exe",
        "C:\\Program Files\\glpk\\glpsol.exe",
        "C:\\Program Files (x86)\\glpk\\glpsol.exe"
    ]
    
    for path in potential_paths:
        if os.path.exists(path):
            print(f"Found GLPK executable at: {path}")
            return path
    
    print("GLPK executable not found in expected locations.")
    return None

def solve_two_stage_stochastic_program(num_scenarios=5, seed=42):
    """
    Solve a two-stage stochastic programming problem for a simple resource allocation example.
    
    This example models a production planning problem:
    - First stage: Decide how much to produce before knowing demand
    - Second stage: After observing demand, decide how much to sell or store
    
    Parameters:
    -----------
    num_scenarios : int
        Number of demand scenarios to generate
    seed : int
        Random seed for reproducibility
    
    Returns:
    --------
    dict
        Dictionary containing the optimal production quantity, expected cost,
        and detailed information for each scenario
    """
    # Set random seed for reproducibility
    np.random.seed(seed)
    
    # Problem parameters
    production_cost = 10
    storage_cost = 2
    shortage_cost = 20
    selling_price = 15
    
    # Generate random demand scenarios
    base_demand = 100
    demand_scenarios = base_demand + np.random.normal(0, 20, num_scenarios)
    scenario_probs = np.ones(num_scenarios) / num_scenarios  # Equal probability
    
    # Create the Pyomo concrete model
    model = pyo.ConcreteModel()
    
    # First stage decision variable: how much to produce
    model.produce = pyo.Var(domain=pyo.NonNegativeReals)
    
    # Second stage variables - for each scenario
    model.scenarios = pyo.RangeSet(0, num_scenarios-1)
    model.sell = pyo.Var(model.scenarios, domain=pyo.NonNegativeReals)
    model.store = pyo.Var(model.scenarios, domain=pyo.NonNegativeReals)
    model.shortage = pyo.Var(model.scenarios, domain=pyo.NonNegativeReals)
    
    # First stage objective: minimize production cost
    model.first_stage_cost = pyo.Expression(expr=production_cost * model.produce)
    
    # Second stage objective: expected profit/cost across all scenarios
    def second_stage_rule(model, s):
        return (scenario_probs[s] * 
                (selling_price * model.sell[s] - 
                 storage_cost * model.store[s] - 
                 shortage_cost * model.shortage[s]))
    
    model.second_stage_obj = pyo.Expression(model.scenarios, rule=second_stage_rule)
    
    # Total objective: first stage cost + expected second stage cost
    model.obj = pyo.Objective(
        expr=model.first_stage_cost - sum(model.second_stage_obj[s] for s in model.scenarios),
        sense=pyo.minimize
    )
    
    # Constraints
    
    # For each scenario, amount sold + stored equals amount produced
    def balance_rule(model, s):
        return model.sell[s] + model.store[s] == model.produce
    
    model.balance = pyo.Constraint(model.scenarios, rule=balance_rule)
    
    # For each scenario, amount sold + shortage equals demand
    def demand_rule(model, s):
        return model.sell[s] + model.shortage[s] == demand_scenarios[s]
    
    model.demand = pyo.Constraint(model.scenarios, rule=demand_rule)
    
    # Set up the solver
    solver = None
    
    # Try to find GLPK executable
    glpk_path = find_glpk_executable()
    
    if glpk_path:
        # Create solver with explicit executable path
        try:
            solver = SolverFactory('glpk', executable=glpk_path)
            print("Using GLPK solver with explicit path")
        except:
            solver = None
    
    # If GLPK isn't available, try other solvers
    if solver is None:
        for solver_name in ['cbc', 'ipopt', 'glpk_direct', 'scip']:
            try:
                solver = SolverFactory(solver_name)
                if solver.available():
                    print(f"Using {solver_name} solver")
                    break
                else:
                    solver = None
            except:
                solver = None
                continue
    
    # If no solver is available, solve with a simple method instead
    if solver is None:
        print("WARNING: No solver available. Using a simple approximation method.")
        # Simplified solution: produce the average demand to minimize expected costs
        optimal_production = np.mean(demand_scenarios)
        expected_cost = production_cost * optimal_production
        
        results = {
            'optimal_production': optimal_production,
            'expected_cost': expected_cost,
            'scenarios': []
        }
        
        for s in range(num_scenarios):
            sold = min(optimal_production, demand_scenarios[s])
            stored = max(0, optimal_production - demand_scenarios[s])
            shortage = max(0, demand_scenarios[s] - optimal_production)
            
            scenario_result = {
                'scenario': s,
                'demand': demand_scenarios[s],
                'sold': sold,
                'stored': stored,
                'shortage': shortage
            }
            results['scenarios'].append(scenario_result)
            
        return results
    
    # Solve the model with the available solver
    result = solver.solve(model)
    
    # Check if the solver found a solution
    if (result.solver.status == pyo.SolverStatus.ok and 
        result.solver.termination_condition == pyo.TerminationCondition.optimal):
        # Extract and return results
        results = {
            'optimal_production': pyo.value(model.produce),
            'expected_cost': pyo.value(model.obj),
            'scenarios': []
        }
        
        for s in model.scenarios:
            scenario_result = {
                'scenario': s,
                'demand': demand_scenarios[s],
                'sold': pyo.value(model.sell[s]),
                'stored': pyo.value(model.store[s]),
                'shortage': pyo.value(model.shortage[s])
            }
            results['scenarios'].append(scenario_result)
            
        return results
    else:
        print(f"Solver status: {result.solver.status}")
        print(f"Termination condition: {result.solver.termination_condition}")
        raise Exception("The solver failed to find a solution.")

# %%
# Example usage
if __name__ == "__main__":
    print("Python executable:", sys.executable)
    print("PATH environment variable:", os.environ.get('PATH'))
    
    # Solve with different numbers of scenarios
    for num_scenarios in [100, 500]:
        print(f"\nSolving with {num_scenarios} scenarios:")
        try:
            results = solve_two_stage_stochastic_program(num_scenarios=num_scenarios)
            print(f"Optimal production quantity: {results['optimal_production']:.2f}")
            print(f"Expected total cost: {results['expected_cost']:.2f}")
            
            # Print details for first 3 scenarios
            for i, scenario in enumerate(results['scenarios'][:3]):
                print(f"\nScenario {i}:")
                print(f"  Demand: {scenario['demand']:.2f}")
                print(f"  Sold: {scenario['sold']:.2f}")
                print(f"  Stored: {scenario['stored']:.2f}")
                print(f"  Shortage: {scenario['shortage']:.2f}")
        except Exception as e:
            print(f"Error: {str(e)}")
            print("Trying alternative approach...")
            
            # If the main approach fails, try a direct approach with the solver
            try:
                # Print information about available solvers
                print("\nChecking available solvers:")
                for solver_name in ['glpk', 'cbc', 'ipopt', 'glpk_direct']:
                    solver = SolverFactory(solver_name)
                    print(f"Solver {solver_name} available: {solver.available()}")
            except:
                print("Could not check solvers.")
# Out:
# Python executable: /Users/muntazirabidi/miniconda3/envs/ai_learning/bin/python
# PATH environment variable: /Users/muntazirabidi/miniconda3/envs/ai_learning/bin:/Users/muntazirabidi/.nvm/versions/node/v18.20.4/bin:/Users/muntazirabidi/miniconda3/bin:/Users/muntazirabidi/miniconda3/condabin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/Library/TeX/texbin:/Users/muntazirabidi/.local/bin:/Users/muntazirabidi/.nvm/versions/node/v18.20.4/bin:/Users/muntazirabidi/miniconda3/bin:/Users/muntazirabidi/miniconda3/condabin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/Library/TeX/texbin:/Users/muntazirabidi/.local/bin
#
# Solving with 100 scenarios:
# GLPK executable not found in expected locations.
# Using cbc solver
# Optimal production quantity: 106.48
# Expected total cost: -252.95
#
# Scenario 0:
#   Demand: 109.93
#   Sold: 106.48
#   Stored: 0.00
#   Shortage: 3.45
#
# Scenario 1:
#   Demand: 97.23
#   Sold: 97.23
#   Stored: 9.25
#   Shortage: 0.00
#
# Scenario 2:
#   Demand: 112.95
#   Sold: 106.48
#   Stored: 0.00
#   Shortage: 6.47
#
# Solving with 500 scenarios:
# GLPK executable not found in expected locations.
# Using cbc solver
# Optimal production quantity: 108.26
# Expected total cost: -239.54
#
# Scenario 0:
#   Demand: 109.93
#   Sold: 108.26
#   Stored: 0.00
#   Shortage: 1.68
#
# Scenario 1:
#   Demand: 97.23
#   Sold: 97.23
#   Stored: 11.02
#   Shortage: 0.00
#
# Scenario 2:
#   Demand: 112.95
#   Sold: 108.26
#   Stored: 0.00
#   Shortage: 4.70

# %%
results
# Out:
# {'optimal_production': 108.25562,
#  'expected_cost': -239.5357137140868,
#  'scenarios': [{'scenario': 0,
#    'demand': 109.93428306022466,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 1.6786645},
#   {'scenario': 1,
#    'demand': 97.2347139765763,
#    'sold': 97.234714,
#    'stored': 11.020905,
#    'shortage': 0.0},
#   {'scenario': 2,
#    'demand': 112.95377076201385,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 4.6981522},
#   {'scenario': 3,
#    'demand': 130.46059712816052,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 22.204979},
#   {'scenario': 4,
#    'demand': 95.31693250553329,
#    'sold': 95.316933,
#    'stored': 12.938686,
#    'shortage': 0.0},
#   {'scenario': 5,
#    'demand': 95.3172608610164,
#    'sold': 95.317261,
#    'stored': 12.938358,
#    'shortage': 0.0},
#   {'scenario': 6,
#    'demand': 131.58425631014782,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 23.328638},
#   {'scenario': 7,
#    'demand': 115.34869458305818,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 7.093076},
#   {'scenario': 8,
#    'demand': 90.61051228130096,
#    'sold': 90.610512,
#    'stored': 17.645106,
#    'shortage': 0.0},
#   {'scenario': 9,
#    'demand': 110.8512008717193,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 2.5955823},
#   {'scenario': 10,
#    'demand': 90.73164614375075,
#    'sold': 90.731646,
#    'stored': 17.523972,
#    'shortage': 0.0},
#   {'scenario': 11,
#    'demand': 90.68540492859486,
#    'sold': 90.685405,
#    'stored': 17.570214,
#    'shortage': 0.0},
#   {'scenario': 12,
#    'demand': 104.83924543132068,
#    'sold': 104.83925,
#    'stored': 3.4163731,
#    'shortage': 0.0},
#   {'scenario': 13,
#    'demand': 61.73439510684404,
#    'sold': 61.734395,
#    'stored': 46.521223,
#    'shortage': 0.0},
#   {'scenario': 14,
#    'demand': 65.50164334973934,
#    'sold': 65.501643,
#    'stored': 42.753975,
#    'shortage': 0.0},
#   {'scenario': 15,
#    'demand': 88.75424941518054,
#    'sold': 88.754249,
#    'stored': 19.501369,
#    'shortage': 0.0},
#   {'scenario': 16,
#    'demand': 79.74337759331152,
#    'sold': 79.743378,
#    'stored': 28.512241,
#    'shortage': 0.0},
#   {'scenario': 17,
#    'demand': 106.28494665190547,
#    'sold': 106.28495,
#    'stored': 1.9706719,
#    'shortage': 0.0},
#   {'scenario': 18,
#    'demand': 81.83951848957578,
#    'sold': 81.839518,
#    'stored': 26.4161,
#    'shortage': 0.0},
#   {'scenario': 19,
#    'demand': 71.75392597329417,
#    'sold': 71.753926,
#    'stored': 36.501693,
#    'shortage': 0.0},
#   {'scenario': 20,
#    'demand': 129.31297537843108,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 21.057357},
#   {'scenario': 21,
#    'demand': 95.4844739902693,
#    'sold': 95.484474,
#    'stored': 12.771145,
#    'shortage': 0.0},
#   {'scenario': 22,
#    'demand': 101.35056409375848,
#    'sold': 101.35056,
#    'stored': 6.9050544,
#    'shortage': 0.0},
#   {'scenario': 23,
#    'demand': 71.50503627573087,
#    'sold': 71.505036,
#    'stored': 36.750582,
#    'shortage': 0.0},
#   {'scenario': 24,
#    'demand': 89.11234550949635,
#    'sold': 89.112346,
#    'stored': 19.143273,
#    'shortage': 0.0},
#   {'scenario': 25,
#    'demand': 102.21845179419732,
#    'sold': 102.21845,
#    'stored': 6.0371667,
#    'shortage': 0.0},
#   {'scenario': 26,
#    'demand': 76.98012845155395,
#    'sold': 76.980128,
#    'stored': 31.27549,
#    'shortage': 0.0},
#   {'scenario': 27,
#    'demand': 107.51396036691344,
#    'sold': 107.51396,
#    'stored': 0.74165817,
#    'shortage': 0.0},
#   {'scenario': 28,
#    'demand': 87.9872262016239,
#    'sold': 87.987226,
#    'stored': 20.268392,
#    'shortage': 0.0},
#   {'scenario': 29,
#    'demand': 94.16612500413447,
#    'sold': 94.166125,
#    'stored': 14.089494,
#    'shortage': 0.0},
#   {'scenario': 30,
#    'demand': 87.96586775541206,
#    'sold': 87.965868,
#    'stored': 20.289751,
#    'shortage': 0.0},
#   {'scenario': 31,
#    'demand': 137.04556369017877,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 28.789945},
#   {'scenario': 32,
#    'demand': 99.73005550524132,
#    'sold': 99.730056,
#    'stored': 8.525563,
#    'shortage': 0.0},
#   {'scenario': 33,
#    'demand': 78.845781420882,
#    'sold': 78.845781,
#    'stored': 29.409837,
#    'shortage': 0.0},
#   {'scenario': 34,
#    'demand': 116.45089824206377,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 8.1952797},
#   {'scenario': 35,
#    'demand': 75.58312700057955,
#    'sold': 75.583127,
#    'stored': 32.672492,
#    'shortage': 0.0},
#   {'scenario': 36,
#    'demand': 104.1772719000951,
#    'sold': 104.17727,
#    'stored': 4.0783466,
#    'shortage': 0.0},
#   {'scenario': 37,
#    'demand': 60.80659752240449,
#    'sold': 60.806598,
#    'stored': 47.449021,
#    'shortage': 0.0},
#   {'scenario': 38,
#    'demand': 73.43627902203139,
#    'sold': 73.436279,
#    'stored': 34.81934,
#    'shortage': 0.0},
#   {'scenario': 39,
#    'demand': 103.93722471738246,
#    'sold': 103.93722,
#    'stored': 4.3183938,
#    'shortage': 0.0},
#   {'scenario': 40,
#    'demand': 114.76933159990821,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 6.5137131},
#   {'scenario': 41,
#    'demand': 103.4273656237994,
#    'sold': 103.42737,
#    'stored': 4.8282529,
#    'shortage': 0.0},
#   {'scenario': 42,
#    'demand': 97.68703435223519,
#    'sold': 97.687034,
#    'stored': 10.568584,
#    'shortage': 0.0},
#   {'scenario': 43,
#    'demand': 93.97792608821422,
#    'sold': 93.977926,
#    'stored': 14.277692,
#    'shortage': 0.0},
#   {'scenario': 44,
#    'demand': 70.42956019265145,
#    'sold': 70.42956,
#    'stored': 37.826058,
#    'shortage': 0.0},
#   {'scenario': 45,
#    'demand': 85.60311583210583,
#    'sold': 85.603116,
#    'stored': 22.652503,
#    'shortage': 0.0},
#   {'scenario': 46,
#    'demand': 90.78722458080425,
#    'sold': 90.787225,
#    'stored': 17.468394,
#    'shortage': 0.0},
#   {'scenario': 47,
#    'demand': 121.1424445243783,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 12.886826},
#   {'scenario': 48,
#    'demand': 106.87236579136923,
#    'sold': 106.87237,
#    'stored': 1.3832527,
#    'shortage': 0.0},
#   {'scenario': 49,
#    'demand': 64.73919689274533,
#    'sold': 64.739197,
#    'stored': 43.516422,
#    'shortage': 0.0},
#   {'scenario': 50,
#    'demand': 106.4816793878959,
#    'sold': 106.48168,
#    'stored': 1.7739392,
#    'shortage': 0.0},
#   {'scenario': 51,
#    'demand': 92.29835439167367,
#    'sold': 92.298354,
#    'stored': 15.957264,
#    'shortage': 0.0},
#   {'scenario': 52,
#    'demand': 86.46155999388083,
#    'sold': 86.46156,
#    'stored': 21.794059,
#    'shortage': 0.0},
#   {'scenario': 53,
#    'demand': 112.23352577681736,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 3.9779072},
#   {'scenario': 54,
#    'demand': 120.61999044991902,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 12.364372},
#   {'scenario': 55,
#    'demand': 118.62560238232398,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 10.369984},
#   {'scenario': 56,
#    'demand': 83.21564953554723,
#    'sold': 83.21565,
#    'stored': 25.039969,
#    'shortage': 0.0},
#   {'scenario': 57,
#    'demand': 93.81575248297571,
#    'sold': 93.815752,
#    'stored': 14.439866,
#    'shortage': 0.0},
#   {'scenario': 58,
#    'demand': 106.62526862807128,
#    'sold': 106.62527,
#    'stored': 1.6303499,
#    'shortage': 0.0},
#   {'scenario': 59,
#    'demand': 119.51090254244718,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 11.255284},
#   {'scenario': 60,
#    'demand': 90.4165152430942,
#    'sold': 90.416515,
#    'stored': 17.839103,
#    'shortage': 0.0},
#   {'scenario': 61,
#    'demand': 96.28682046672365,
#    'sold': 96.28682,
#    'stored': 11.968798,
#    'shortage': 0.0},
#   {'scenario': 62,
#    'demand': 77.87330051987944,
#    'sold': 77.873301,
#    'stored': 30.382318,
#    'shortage': 0.0},
#   {'scenario': 63,
#    'demand': 76.07586751838659,
#    'sold': 76.075868,
#    'stored': 32.179751,
#    'shortage': 0.0},
#   {'scenario': 64,
#    'demand': 116.25051644788397,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 7.9948979},
#   {'scenario': 65,
#    'demand': 127.12480057141646,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 18.869182},
#   {'scenario': 66,
#    'demand': 98.55979756839332,
#    'sold': 98.559798,
#    'stored': 9.695821,
#    'shortage': 0.0},
#   {'scenario': 67,
#    'demand': 120.07065795784048,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 11.815039},
#   {'scenario': 68,
#    'demand': 107.23272050095268,
#    'sold': 107.23272,
#    'stored': 1.022898,
#    'shortage': 0.0},
#   {'scenario': 69,
#    'demand': 87.09760490789752,
#    'sold': 87.097605,
#    'stored': 21.158014,
#    'shortage': 0.0},
#   {'scenario': 70,
#    'demand': 107.22791211016828,
#    'sold': 107.22791,
#    'stored': 1.0277064,
#    'shortage': 0.0},
#   {'scenario': 71,
#    'demand': 130.76073132931938,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 22.505113},
#   {'scenario': 72,
#    'demand': 99.28347921780097,
#    'sold': 99.283479,
#    'stored': 8.9721393,
#    'shortage': 0.0},
#   {'scenario': 73,
#    'demand': 131.29287311628013,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 23.037255},
#   {'scenario': 74,
#    'demand': 47.60509791820511,
#    'sold': 47.605098,
#    'stored': 60.650521,
#    'shortage': 0.0},
#   {'scenario': 75,
#    'demand': 116.43805008750448,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 8.1824315},
#   {'scenario': 76,
#    'demand': 101.74094136476343,
#    'sold': 101.74094,
#    'stored': 6.5146772,
#    'shortage': 0.0},
#   {'scenario': 77,
#    'demand': 94.01985299068264,
#    'sold': 94.019853,
#    'stored': 14.235766,
#    'shortage': 0.0},
#   {'scenario': 78,
#    'demand': 101.83521553071004,
#    'sold': 101.83522,
#    'stored': 6.420403,
#    'shortage': 0.0},
#   {'scenario': 79,
#    'demand': 60.248621707982146,
#    'sold': 60.248622,
#    'stored': 48.006997,
#    'shortage': 0.0},
#   {'scenario': 80,
#    'demand': 95.60656224324975,
#    'sold': 95.606562,
#    'stored': 12.649056,
#    'shortage': 0.0},
#   {'scenario': 81,
#    'demand': 107.14225143023492,
#    'sold': 107.14225,
#    'stored': 1.1133671,
#    'shortage': 0.0},
#   {'scenario': 82,
#    'demand': 129.55788089483033,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 21.302262},
#   {'scenario': 83,
#    'demand': 89.63459563452705,
#    'sold': 89.634596,
#    'stored': 18.621023,
#    'shortage': 0.0},
#   {'scenario': 84,
#    'demand': 83.83012794213624,
#    'sold': 83.830128,
#    'stored': 24.425491,
#    'shortage': 0.0},
#   {'scenario': 85,
#    'demand': 89.96485912830927,
#    'sold': 89.964859,
#    'stored': 18.290759,
#    'shortage': 0.0},
#   {'scenario': 86,
#    'demand': 118.30804235404148,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 10.052424},
#   {'scenario': 87,
#    'demand': 106.57502219319369,
#    'sold': 106.57502,
#    'stored': 1.6805963,
#    'shortage': 0.0},
#   {'scenario': 88,
#    'demand': 89.40479592465923,
#    'sold': 89.404796,
#    'stored': 18.850823,
#    'shortage': 0.0},
#   {'scenario': 89,
#    'demand': 110.26534866226712,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 2.0097301},
#   {'scenario': 90,
#    'demand': 101.9415509869608,
#    'sold': 101.94155,
#    'stored': 6.3140676,
#    'shortage': 0.0},
#   {'scenario': 91,
#    'demand': 119.37289981065778,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 11.117281},
#   {'scenario': 92,
#    'demand': 85.95893812245295,
#    'sold': 85.958938,
#    'stored': 22.29668,
#    'shortage': 0.0},
#   {'scenario': 93,
#    'demand': 93.44675706804463,
#    'sold': 93.446757,
#    'stored': 14.808861,
#    'shortage': 0.0},
#   {'scenario': 94,
#    'demand': 92.15783693735685,
#    'sold': 92.157837,
#    'stored': 16.097782,
#    'shortage': 0.0},
#   {'scenario': 95,
#    'demand': 70.72970103735763,
#    'sold': 70.729701,
#    'stored': 37.525918,
#    'shortage': 0.0},
#   {'scenario': 96,
#    'demand': 105.92240554129152,
#    'sold': 105.92241,
#    'stored': 2.333213,
#    'shortage': 0.0},
#   {'scenario': 97,
#    'demand': 105.22110544359779,
#    'sold': 105.22111,
#    'stored': 3.0345131,
#    'shortage': 0.0},
#   {'scenario': 98,
#    'demand': 100.10226913284922,
#    'sold': 100.10227,
#    'stored': 8.1533494,
#    'shortage': 0.0},
#   {'scenario': 99,
#    'demand': 95.30825733249705,
#    'sold': 95.308257,
#    'stored': 12.947361,
#    'shortage': 0.0},
#   {'scenario': 100,
#    'demand': 71.69258515899172,
#    'sold': 71.692585,
#    'stored': 36.563033,
#    'shortage': 0.0},
#   {'scenario': 101,
#    'demand': 91.58709354469282,
#    'sold': 91.587094,
#    'stored': 16.668525,
#    'shortage': 0.0},
#   {'scenario': 102,
#    'demand': 93.14570966946461,
#    'sold': 93.14571,
#    'stored': 15.109909,
#    'shortage': 0.0},
#   {'scenario': 103,
#    'demand': 83.95445461556761,
#    'sold': 83.954455,
#    'stored': 24.301164,
#    'shortage': 0.0},
#   {'scenario': 104,
#    'demand': 96.77428576667981,
#    'sold': 96.774286,
#    'stored': 11.481333,
#    'shortage': 0.0},
#   {'scenario': 105,
#    'demand': 108.08101713629077,
#    'sold': 108.08102,
#    'stored': 0.1746014,
#    'shortage': 0.0},
#   {'scenario': 106,
#    'demand': 137.7237180242106,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 29.468099},
#   {'scenario': 107,
#    'demand': 103.49155625663678,
#    'sold': 103.49156,
#    'stored': 4.7640623,
#    'shortage': 0.0},
#   {'scenario': 108,
#    'demand': 105.15100781445528,
#    'sold': 105.15101,
#    'stored': 3.1046107,
#    'shortage': 0.0},
#   {'scenario': 109,
#    'demand': 98.51108168467665,
#    'sold': 98.511082,
#    'stored': 9.7445369,
#    'shortage': 0.0},
#   {'scenario': 110,
#    'demand': 61.62457569401917,
#    'sold': 61.624576,
#    'stored': 46.631043,
#    'shortage': 0.0},
#   {'scenario': 111,
#    'demand': 99.46972249101566,
#    'sold': 99.469722,
#    'stored': 8.785896,
#    'shortage': 0.0},
#   {'scenario': 112,
#    'demand': 101.20460419882053,
#    'sold': 101.2046,
#    'stored': 7.0510143,
#    'shortage': 0.0},
#   {'scenario': 113,
#    'demand': 149.26484224970574,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 41.009224},
#   {'scenario': 114,
#    'demand': 96.15278070437755,
#    'sold': 96.152781,
#    'stored': 12.102838,
#    'shortage': 0.0},
#   {'scenario': 115,
#    'demand': 106.03094684667225,
#    'sold': 106.03095,
#    'stored': 2.2246717,
#    'shortage': 0.0},
#   {'scenario': 116,
#    'demand': 99.30576460589513,
#    'sold': 99.305765,
#    'stored': 8.9498539,
#    'shortage': 0.0},
#   {'scenario': 117,
#    'demand': 76.62643924760935,
#    'sold': 76.626439,
#    'stored': 31.629179,
#    'shortage': 0.0},
#   {'scenario': 118,
#    'demand': 122.85645629030041,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 14.600838},
#   {'scenario': 119,
#    'demand': 115.03866065373549,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 6.7830421},
#   {'scenario': 120,
#    'demand': 115.82063894086093,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 7.5650204},
#   {'scenario': 121,
#    'demand': 81.81225090410521,
#    'sold': 81.812251,
#    'stored': 26.443368,
#    'shortage': 0.0},
#   {'scenario': 122,
#    'demand': 128.05588621872198,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 19.800268},
#   {'scenario': 123,
#    'demand': 71.96297874415438,
#    'sold': 71.962979,
#    'stored': 36.29264,
#    'shortage': 0.0},
#   {'scenario': 124,
#    'demand': 111.73714187600541,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 3.4815233},
#   {'scenario': 125,
#    'demand': 143.80911251619958,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 35.553494},
#   {'scenario': 126,
#    'demand': 80.18927349738624,
#    'sold': 80.189273,
#    'stored': 28.066345,
#    'shortage': 0.0},
#   {'scenario': 127,
#    'demand': 88.67404540794456,
#    'sold': 88.674045,
#    'stored': 19.581573,
#    'shortage': 0.0},
#   {'scenario': 128,
#    'demand': 101.99302730175282,
#    'sold': 101.99303,
#    'stored': 6.2625912,
#    'shortage': 0.0},
#   {'scenario': 129,
#    'demand': 89.93048691767602,
#    'sold': 89.930487,
#    'stored': 18.325132,
#    'shortage': 0.0},
#   {'scenario': 130,
#    'demand': 68.98673137867735,
#    'sold': 68.986731,
#    'stored': 39.268887,
#    'shortage': 0.0},
#   {'scenario': 131,
#    'demand': 101.37125949612054,
#    'sold': 101.37126,
#    'stored': 6.884359,
#    'shortage': 0.0},
#   {'scenario': 132,
#    'demand': 78.7539257254779,
#    'sold': 78.753926,
#    'stored': 29.501693,
#    'shortage': 0.0},
#   {'scenario': 133,
#    'demand': 109.47184861270364,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 1.2162301},
#   {'scenario': 134,
#    'demand': 81.61151531532393,
#    'sold': 81.611515,
#    'stored': 26.644103,
#    'shortage': 0.0},
#   {'scenario': 135,
#    'demand': 130.9986881003508,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 22.74307},
#   {'scenario': 136,
#    'demand': 84.33493415327526,
#    'sold': 84.334934,
#    'stored': 23.920684,
#    'shortage': 0.0},
#   {'scenario': 137,
#    'demand': 93.55876967588648,
#    'sold': 93.55877,
#    'stored': 14.696849,
#    'shortage': 0.0},
#   {'scenario': 138,
#    'demand': 116.27034434739339,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 8.0147258},
#   {'scenario': 139,
#    'demand': 75.3827136713209,
#    'sold': 75.382714,
#    'stored': 32.872905,
#    'shortage': 0.0},
#   {'scenario': 140,
#    'demand': 104.54919869208258,
#    'sold': 104.5492,
#    'stored': 3.7064198,
#    'shortage': 0.0},
#   {'scenario': 141,
#    'demand': 126.14285508564856,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 17.887237},
#   {'scenario': 142,
#    'demand': 67.85033530877544,
#    'sold': 67.850335,
#    'stored': 40.405283,
#    'shortage': 0.0},
#   {'scenario': 143,
#    'demand': 103.69267717064608,
#    'sold': 103.69268,
#    'stored': 4.5629414,
#    'shortage': 0.0},
#   {'scenario': 144,
#    'demand': 105.19765588496847,
#    'sold': 105.19766,
#    'stored': 3.0579627,
#    'shortage': 0.0},
#   {'scenario': 145,
#    'demand': 115.6364574355462,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 7.3808389},
#   {'scenario': 146,
#    'demand': 75.26098578243835,
#    'sold': 75.260986,
#    'stored': 32.994633,
#    'shortage': 0.0},
#   {'scenario': 147,
#    'demand': 73.59086773831447,
#    'sold': 73.590868,
#    'stored': 34.664751,
#    'shortage': 0.0},
#   {'scenario': 148,
#    'demand': 110.43883131233795,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 2.1832128},
#   {'scenario': 149,
#    'demand': 105.93969346466372,
#    'sold': 105.93969,
#    'stored': 2.3159251,
#    'shortage': 0.0},
#   {'scenario': 150,
#    'demand': 105.00985700691753,
#    'sold': 105.00986,
#    'stored': 3.2457615,
#    'shortage': 0.0},
#   {'scenario': 151,
#    'demand': 106.92896418993952,
#    'sold': 106.92896,
#    'stored': 1.3266543,
#    'shortage': 0.0},
#   {'scenario': 152,
#    'demand': 86.39950556843019,
#    'sold': 86.399506,
#    'stored': 21.856113,
#    'shortage': 0.0},
#   {'scenario': 153,
#    'demand': 104.64507394322007,
#    'sold': 104.64507,
#    'stored': 3.6105446,
#    'shortage': 0.0},
#   {'scenario': 154,
#    'demand': 105.86144946597362,
#    'sold': 105.86145,
#    'stored': 2.3941691,
#    'shortage': 0.0},
#   {'scenario': 155,
#    'demand': 85.71297163947264,
#    'sold': 85.712972,
#    'stored': 22.542647,
#    'shortage': 0.0},
#   {'scenario': 156,
#    'demand': 137.31549022289514,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 29.059872},
#   {'scenario': 157,
#    'demand': 109.47665841823576,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 1.2210399},
#   {'scenario': 158,
#    'demand': 76.17393005594703,
#    'sold': 76.17393,
#    'stored': 32.081688,
#    'shortage': 0.0},
#   {'scenario': 159,
#    'demand': 113.1310721726766,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 4.8754536},
#   {'scenario': 160,
#    'demand': 80.50636659545357,
#    'sold': 80.506367,
#    'stored': 27.749252,
#    'shortage': 0.0},
#   {'scenario': 161,
#    'demand': 115.74169207484904,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 7.4860735},
#   {'scenario': 162,
#    'demand': 123.17191158014808,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 14.916293},
#   {'scenario': 163,
#    'demand': 83.5863536329658,
#    'sold': 83.586354,
#    'stored': 24.669265,
#    'shortage': 0.0},
#   {'scenario': 164,
#    'demand': 119.26752258488644,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 11.011904},
#   {'scenario': 165,
#    'demand': 108.25561853872996,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 0.0},
#   {'scenario': 166,
#    'demand': 116.4412031998898,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 8.1855847},
#   {'scenario': 167,
#    'demand': 137.93585965307895,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 29.680241},
#   {'scenario': 168,
#    'demand': 95.09223767994258,
#    'sold': 95.092238,
#    'stored': 13.163381,
#    'shortage': 0.0},
#   {'scenario': 169,
#    'demand': 84.9252767128502,
#    'sold': 84.925277,
#    'stored': 23.330342,
#    'shortage': 0.0},
#   {'scenario': 170,
#    'demand': 82.20971140748954,
#    'sold': 82.209711,
#    'stored': 26.045907,
#    'shortage': 0.0},
#   {'scenario': 171,
#    'demand': 83.68379430069123,
#    'sold': 83.683794,
#    'stored': 24.571824,
#    'shortage': 0.0},
#   {'scenario': 172,
#    'demand': 98.45796581171791,
#    'sold': 98.457966,
#    'stored': 9.7976527,
#    'shortage': 0.0},
#   {'scenario': 173,
#    'demand': 106.82303949633287,
#    'sold': 106.82304,
#    'stored': 1.432579,
#    'shortage': 0.0},
#   {'scenario': 174,
#    'demand': 105.53381598660039,
#    'sold': 105.53382,
#    'stored': 2.7218026,
#    'shortage': 0.0},
#   {'scenario': 175,
#    'demand': 116.54366498072048,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 8.2880464},
#   {'scenario': 176,
#    'demand': 100.26003783755814,
#    'sold': 100.26004,
#    'stored': 7.9955807,
#    'shortage': 0.0},
#   {'scenario': 177,
#    'demand': 129.07068154314635,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 20.815063},
#   {'scenario': 178,
#    'demand': 94.70686333524088,
#    'sold': 94.706863,
#    'stored': 13.548755,
#    'shortage': 0.0},
#   {'scenario': 179,
#    'demand': 154.40338333179238,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 46.147765},
#   {'scenario': 180,
#    'demand': 112.51334695530012,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 4.2577284},
#   {'scenario': 181,
#    'demand': 82.85684887167434,
#    'sold': 82.856849,
#    'stored': 25.39877,
#    'shortage': 0.0},
#   {'scenario': 182,
#    'demand': 78.58215003877775,
#    'sold': 78.58215,
#    'stored': 29.673468,
#    'shortage': 0.0},
#   {'scenario': 183,
#    'demand': 109.64944830486371,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 1.3938298},
#   {'scenario': 184,
#    'demand': 95.53074429348298,
#    'sold': 95.530744,
#    'stored': 12.724874,
#    'shortage': 0.0},
#   {'scenario': 185,
#    'demand': 114.28000988184183,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 6.0243913},
#   {'scenario': 186,
#    'demand': 109.4647524914709,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 1.209134},
#   {'scenario': 187,
#    'demand': 98.54342174686255,
#    'sold': 98.543422,
#    'stored': 9.7121968,
#    'shortage': 0.0},
#   {'scenario': 188,
#    'demand': 83.06412563863191,
#    'sold': 83.064126,
#    'stored': 25.191493,
#    'shortage': 0.0},
#   {'scenario': 189,
#    'demand': 69.70305550628271,
#    'sold': 69.703056,
#    'stored': 38.552563,
#    'shortage': 0.0},
#   {'scenario': 190,
#    'demand': 91.06970095865958,
#    'sold': 91.069701,
#    'stored': 17.185918,
#    'shortage': 0.0},
#   {'scenario': 191,
#    'demand': 117.12797588646944,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 8.8723573},
#   {'scenario': 192,
#    'demand': 104.28187488260409,
#    'sold': 104.28187,
#    'stored': 3.9737437,
#    'shortage': 0.0},
#   {'scenario': 193,
#    'demand': 75.08522442576023,
#    'sold': 75.085224,
#    'stored': 33.170394,
#    'shortage': 0.0},
#   {'scenario': 194,
#    'demand': 103.46361851702363,
#    'sold': 103.46362,
#    'stored': 4.792,
#    'shortage': 0.0},
#   {'scenario': 195,
#    'demand': 107.70634759457674,
#    'sold': 107.70635,
#    'stored': 0.54927094,
#    'shortage': 0.0},
#   {'scenario': 196,
#    'demand': 82.32285127597734,
#    'sold': 82.322851,
#    'stored': 25.932767,
#    'shortage': 0.0},
#   {'scenario': 197,
#    'demand': 103.07450211891056,
#    'sold': 103.0745,
#    'stored': 5.1811164,
#    'shortage': 0.0},
#   {'scenario': 198,
#    'demand': 101.16417436892,
#    'sold': 101.16417,
#    'stored': 7.0914442,
#    'shortage': 0.0},
#   {'scenario': 199,
#    'demand': 77.14059404338754,
#    'sold': 77.140594,
#    'stored': 31.115024,
#    'shortage': 0.0},
#   {'scenario': 200,
#    'demand': 107.15574720696567,
#    'sold': 107.15575,
#    'stored': 1.0998713,
#    'shortage': 0.0},
#   {'scenario': 201,
#    'demand': 111.21569052736469,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 2.960072},
#   {'scenario': 202,
#    'demand': 121.66102486350553,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 13.405406},
#   {'scenario': 203,
#    'demand': 121.07604104069806,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 12.820423},
#   {'scenario': 204,
#    'demand': 72.44661264085818,
#    'sold': 72.446613,
#    'stored': 35.809006,
#    'shortage': 0.0},
#   {'scenario': 205,
#    'demand': 81.24349920169755,
#    'sold': 81.243499,
#    'stored': 27.012119,
#    'shortage': 0.0},
#   {'scenario': 206,
#    'demand': 110.3007053441732,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 2.0450868},
#   {'scenario': 207,
#    'demand': 110.27571901824417,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 2.0201005},
#   {'scenario': 208,
#    'demand': 110.30095372612095,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 2.0453352},
#   {'scenario': 209,
#    'demand': 177.0546298130944,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 68.799011},
#   {'scenario': 210,
#    'demand': 111.41781021386333,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 3.1621917},
#   {'scenario': 211,
#    'demand': 122.71131280361197,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 14.455694},
#   {'scenario': 212,
#    'demand': 119.08003526986406,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 10.824417},
#   {'scenario': 213,
#    'demand': 113.02782502611596,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 4.7722065},
#   {'scenario': 214,
#    'demand': 93.69461510719309,
#    'sold': 93.694615,
#    'stored': 14.561003,
#    'shortage': 0.0},
#   {'scenario': 215,
#    'demand': 115.17938440986535,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 6.9237659},
#   {'scenario': 216,
#    'demand': 84.54349570924856,
#    'sold': 84.543496,
#    'stored': 23.712123,
#    'shortage': 0.0},
#   {'scenario': 217,
#    'demand': 95.26362786519982,
#    'sold': 95.263628,
#    'stored': 12.991991,
#    'shortage': 0.0},
#   {'scenario': 218,
#    'demand': 90.29272904341794,
#    'sold': 90.292729,
#    'stored': 17.962889,
#    'shortage': 0.0},
#   {'scenario': 219,
#    'demand': 101.63748278772646,
#    'sold': 101.63748,
#    'stored': 6.6181358,
#    'shortage': 0.0},
#   {'scenario': 220,
#    'demand': 146.29317133347018,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 38.037553},
#   {'scenario': 221,
#    'demand': 62.65469614816504,
#    'sold': 62.654696,
#    'stored': 45.600922,
#    'shortage': 0.0},
#   {'scenario': 222,
#    'demand': 113.72520380749027,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 5.4695853},
#   {'scenario': 223,
#    'demand': 67.74568257620696,
#    'sold': 67.745683,
#    'stored': 40.509936,
#    'shortage': 0.0},
#   {'scenario': 224,
#    'demand': 90.56136268421133,
#    'sold': 90.561363,
#    'stored': 17.694256,
#    'shortage': 0.0},
#   {'scenario': 225,
#    'demand': 121.77901193934733,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 13.523393},
#   {'scenario': 226,
#    'demand': 101.28560038190926,
#    'sold': 101.2856,
#    'stored': 6.9700182,
#    'shortage': 0.0},
#   {'scenario': 227,
#    'demand': 78.44510444141387,
#    'sold': 78.445104,
#    'stored': 29.810514,
#    'shortage': 0.0},
#   {'scenario': 228,
#    'demand': 85.69392581480064,
#    'sold': 85.693926,
#    'stored': 22.561693,
#    'shortage': 0.0},
#   {'scenario': 229,
#    'demand': 113.59195497869352,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 5.3363364},
#   {'scenario': 230,
#    'demand': 85.39266736565727,
#    'sold': 85.392667,
#    'stored': 22.862951,
#    'shortage': 0.0},
#   {'scenario': 231,
#    'demand': 104.3291717916395,
#    'sold': 104.32917,
#    'stored': 3.9264467,
#    'shortage': 0.0},
#   {'scenario': 232,
#    'demand': 100.91143679807628,
#    'sold': 100.91144,
#    'stored': 7.3441817,
#    'shortage': 0.0},
#   {'scenario': 233,
#    'demand': 86.96799304788367,
#    'sold': 86.967993,
#    'stored': 21.287625,
#    'shortage': 0.0},
#   {'scenario': 234,
#    'demand': 142.8788817865065,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 34.623263},
#   {'scenario': 235,
#    'demand': 112.67838044636022,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 4.4227619},
#   {'scenario': 236,
#    'demand': 59.49714826684786,
#    'sold': 59.497148,
#    'stored': 48.75847,
#    'shortage': 0.0},
#   {'scenario': 237,
#    'demand': 103.72908629538856,
#    'sold': 103.72909,
#    'stored': 4.5265322,
#    'shortage': 0.0},
#   {'scenario': 238,
#    'demand': 86.76427070463224,
#    'sold': 86.764271,
#    'stored': 21.491348,
#    'shortage': 0.0},
#   {'scenario': 239,
#    'demand': 117.04866669592448,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 8.7930482},
#   {'scenario': 240,
#    'demand': 84.14958523134598,
#    'sold': 84.149585,
#    'stored': 24.106033,
#    'shortage': 0.0},
#   {'scenario': 241,
#    'demand': 97.70527117066202,
#    'sold': 97.705271,
#    'stored': 10.550347,
#    'shortage': 0.0},
#   {'scenario': 242,
#    'demand': 110.09974557960915,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 1.844127},
#   {'scenario': 243,
#    'demand': 117.31510388340243,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 9.0594853},
#   {'scenario': 244,
#    'demand': 75.99407185888447,
#    'sold': 75.994072,
#    'stored': 32.261547,
#    'shortage': 0.0},
#   {'scenario': 245,
#    'demand': 93.30997528318103,
#    'sold': 93.309975,
#    'stored': 14.945643,
#    'shortage': 0.0},
#   {'scenario': 246,
#    'demand': 90.50109377678088,
#    'sold': 90.501094,
#    'stored': 17.754525,
#    'shortage': 0.0},
#   {'scenario': 247,
#    'demand': 86.93341534852576,
#    'sold': 86.933415,
#    'stored': 21.322203,
#    'shortage': 0.0},
#   {'scenario': 248,
#    'demand': 135.30908480562192,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 27.053466},
#   {'scenario': 249,
#    'demand': 108.09963421921911,
#    'sold': 108.09963,
#    'stored': 0.15598432,
#    'shortage': 0.0},
#   {'scenario': 250,
#    'demand': 74.78232091329909,
#    'sold': 74.782321,
#    'stored': 33.473298,
#    'shortage': 0.0},
#   {'scenario': 251,
#    'demand': 118.35723894109552,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 10.10162},
#   {'scenario': 252,
#    'demand': 142.44312394025266,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 34.187505},
#   {'scenario': 253,
#    'demand': 120.64930521102293,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 12.393687},
#   {'scenario': 254,
#    'demand': 69.61260068091974,
#    'sold': 69.612601,
#    'stored': 38.643018,
#    'shortage': 0.0},
#   {'scenario': 255,
#    'demand': 90.31531854267497,
#    'sold': 90.315319,
#    'stored': 17.9403,
#    'shortage': 0.0},
#   {'scenario': 256,
#    'demand': 125.33822298373245,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 17.082604},
#   {'scenario': 257,
#    'demand': 85.84661068762438,
#    'sold': 85.846611,
#    'stored': 22.409008,
#    'shortage': 0.0},
#   {'scenario': 258,
#    'demand': 108.87638856292457,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 0.62077002},
#   {'scenario': 259,
#    'demand': 115.49268106858673,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 7.2370625},
#   {'scenario': 260,
#    'demand': 81.46139056843833,
#    'sold': 81.461391,
#    'stored': 26.794228,
#    'shortage': 0.0},
#   {'scenario': 261,
#    'demand': 98.809492878764,
#    'sold': 98.809493,
#    'stored': 9.4461257,
#    'shortage': 0.0},
#   {'scenario': 262,
#    'demand': 35.17465319861854,
#    'sold': 35.174653,
#    'stored': 73.080965,
#    'shortage': 0.0},
#   {'scenario': 263,
#    'demand': 79.51224717331421,
#    'sold': 79.512247,
#    'stored': 28.743371,
#    'shortage': 0.0},
#   {'scenario': 264,
#    'demand': 94.9486369721368,
#    'sold': 94.948637,
#    'stored': 13.306982,
#    'shortage': 0.0},
#   {'scenario': 265,
#    'demand': 75.04433636070301,
#    'sold': 75.044336,
#    'stored': 33.211282,
#    'shortage': 0.0},
#   {'scenario': 266,
#    'demand': 132.64822607863272,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 24.392608},
#   {'scenario': 267,
#    'demand': 71.39717244078734,
#    'sold': 71.397172,
#    'stored': 36.858446,
#    'shortage': 0.0},
#   {'scenario': 268,
#    'demand': 91.19911026606033,
#    'sold': 91.19911,
#    'stored': 17.056508,
#    'shortage': 0.0},
#   {'scenario': 269,
#    'demand': 102.61481154572182,
#    'sold': 102.61481,
#    'stored': 5.640807,
#    'shortage': 0.0},
#   {'scenario': 270,
#    'demand': 128.82546578132232,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 20.569847},
#   {'scenario': 271,
#    'demand': 71.2827569764112,
#    'sold': 71.282757,
#    'stored': 36.972862,
#    'shortage': 0.0},
#   {'scenario': 272,
#    'demand': 123.26327504309918,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 15.007657},
#   {'scenario': 273,
#    'demand': 100.20466122039174,
#    'sold': 100.20466,
#    'stored': 8.0509573,
#    'shortage': 0.0},
#   {'scenario': 274,
#    'demand': 80.36982697904098,
#    'sold': 80.369827,
#    'stored': 27.885792,
#    'shortage': 0.0},
#   {'scenario': 275,
#    'demand': 109.24206948526542,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 0.98645095},
#   {'scenario': 276,
#    'demand': 103.9811939114694,
#    'sold': 103.98119,
#    'stored': 4.2744246,
#    'shortage': 0.0},
#   {'scenario': 277,
#    'demand': 87.9956624568241,
#    'sold': 87.995662,
#    'stored': 20.259956,
#    'shortage': 0.0},
#   {'scenario': 278,
#    'demand': 101.39604169980038,
#    'sold': 101.39604,
#    'stored': 6.8595768,
#    'shortage': 0.0},
#   {'scenario': 279,
#    'demand': 92.2937280627648,
#    'sold': 92.293728,
#    'stored': 15.96189,
#    'shortage': 0.0},
#   {'scenario': 280,
#    'demand': 102.27034690502497,
#    'sold': 102.27035,
#    'stored': 5.9852716,
#    'shortage': 0.0},
#   {'scenario': 281,
#    'demand': 113.24261349042092,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 4.986995},
#   {'scenario': 282,
#    'demand': 131.72033632290703,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 23.464718},
#   {'scenario': 283,
#    'demand': 75.24369002346302,
#    'sold': 75.24369,
#    'stored': 33.011929,
#    'shortage': 0.0},
#   {'scenario': 284,
#    'demand': 142.66066749312535,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 34.405049},
#   {'scenario': 285,
#    'demand': 60.958244009549965,
#    'sold': 60.958244,
#    'stored': 47.297375,
#    'shortage': 0.0},
#   {'scenario': 286,
#    'demand': 96.96429809928833,
#    'sold': 96.964298,
#    'stored': 11.29132,
#    'shortage': 0.0},
#   {'scenario': 287,
#    'demand': 111.76634412969152,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 3.5107256},
#   {'scenario': 288,
#    'demand': 105.61983735470065,
#    'sold': 105.61984,
#    'stored': 2.6357812,
#    'shortage': 0.0},
#   {'scenario': 289,
#    'demand': 87.54600960358812,
#    'sold': 87.54601,
#    'stored': 20.709609,
#    'shortage': 0.0},
#   {'scenario': 290,
#    'demand': 95.83755499285449,
#    'sold': 95.837555,
#    'stored': 12.418064,
#    'shortage': 0.0},
#   {'scenario': 291,
#    'demand': 90.13998130682333,
#    'sold': 90.139981,
#    'stored': 18.115637,
#    'shortage': 0.0},
#   {'scenario': 292,
#    'demand': 88.21270486111577,
#    'sold': 88.212705,
#    'stored': 20.042914,
#    'shortage': 0.0},
#   {'scenario': 293,
#    'demand': 116.9920419404205,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 8.7364234},
#   {'scenario': 294,
#    'demand': 107.14030971930094,
#    'sold': 107.14031,
#    'stored': 1.1153088,
#    'shortage': 0.0},
#   {'scenario': 295,
#    'demand': 86.14180809478691,
#    'sold': 86.141808,
#    'stored': 22.11381,
#    'shortage': 0.0},
#   {'scenario': 296,
#    'demand': 117.99199750866501,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 9.736379},
#   {'scenario': 297,
#    'demand': 106.14599041753219,
#    'sold': 106.14599,
#    'stored': 2.1096281,
#    'shortage': 0.0},
#   {'scenario': 298,
#    'demand': 116.2572423767792,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 8.0016238},
#   {'scenario': 299,
#    'demand': 112.59257683847224,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 4.3369583},
#   {'scenario': 300,
#    'demand': 83.42009978155855,
#    'sold': 83.4201,
#    'stored': 24.835519,
#    'shortage': 0.0},
#   {'scenario': 301,
#    'demand': 88.7963791960606,
#    'sold': 88.796379,
#    'stored': 19.459239,
#    'shortage': 0.0},
#   {'scenario': 302,
#    'demand': 114.94587210246523,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 6.6902536},
#   {'scenario': 303,
#    'demand': 112.2074053086693,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 3.9517868},
#   {'scenario': 304,
#    'demand': 99.58196812071704,
#    'sold': 99.581968,
#    'stored': 8.6736504,
#    'shortage': 0.0},
#   {'scenario': 305,
#    'demand': 102.34654766617564,
#    'sold': 102.34655,
#    'stored': 5.9090709,
#    'shortage': 0.0},
#   {'scenario': 306,
#    'demand': 125.5532979157685,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 17.297679},
#   {'scenario': 307,
#    'demand': 88.1685722232834,
#    'sold': 88.168572,
#    'stored': 20.087046,
#    'shortage': 0.0},
#   {'scenario': 308,
#    'demand': 110.94194762340075,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 2.6863291},
#   {'scenario': 309,
#    'demand': 95.95614695132213,
#    'sold': 95.956147,
#    'stored': 12.299472,
#    'shortage': 0.0},
#   {'scenario': 310,
#    'demand': 95.6463759354556,
#    'sold': 95.646376,
#    'stored': 12.609243,
#    'shortage': 0.0},
#   {'scenario': 311,
#    'demand': 121.97553703974381,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 13.719919},
#   {'scenario': 312,
#    'demand': 116.5083269797606,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 8.2527084},
#   {'scenario': 313,
#    'demand': 116.27019272001277,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 8.0145742},
#   {'scenario': 314,
#    'demand': 126.10957614308658,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 17.853958},
#   {'scenario': 315,
#    'demand': 100.42007683265518,
#    'sold': 100.42008,
#    'stored': 7.8355417,
#    'shortage': 0.0},
#   {'scenario': 316,
#    'demand': 113.63905942589928,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 5.3834409},
#   {'scenario': 317,
#    'demand': 93.79466486813088,
#    'sold': 93.794665,
#    'stored': 14.460954,
#    'shortage': 0.0},
#   {'scenario': 318,
#    'demand': 106.48332704976885,
#    'sold': 106.48333,
#    'stored': 1.7722915,
#    'shortage': 0.0},
#   {'scenario': 319,
#    'demand': 97.39713891264631,
#    'sold': 97.397139,
#    'stored': 10.85848,
#    'shortage': 0.0},
#   {'scenario': 320,
#    'demand': 101.93991929985437,
#    'sold': 101.93992,
#    'stored': 6.3156992,
#    'shortage': 0.0},
#   {'scenario': 321,
#    'demand': 111.90314050873828,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 3.647522},
#   {'scenario': 322,
#    'demand': 83.63558633533054,
#    'sold': 83.635586,
#    'stored': 24.620032,
#    'shortage': 0.0},
#   {'scenario': 323,
#    'demand': 141.8477455137092,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 33.592127},
#   {'scenario': 324,
#    'demand': 79.87965237000596,
#    'sold': 79.879652,
#    'stored': 28.375966,
#    'shortage': 0.0},
#   {'scenario': 325,
#    'demand': 75.71622774424536,
#    'sold': 75.716228,
#    'stored': 32.539391,
#    'shortage': 0.0},
#   {'scenario': 326,
#    'demand': 123.16221747000135,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 14.906599},
#   {'scenario': 327,
#    'demand': 115.83325387925872,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 7.5776353},
#   {'scenario': 328,
#    'demand': 112.4823963410431,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 4.2267778},
#   {'scenario': 329,
#    'demand': 112.5669101852856,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 4.3112916},
#   {'scenario': 330,
#    'demand': 99.7550645430617,
#    'sold': 99.755065,
#    'stored': 8.500554,
#    'shortage': 0.0},
#   {'scenario': 331,
#    'demand': 82.05491257028336,
#    'sold': 82.054913,
#    'stored': 26.200706,
#    'shortage': 0.0},
#   {'scenario': 332,
#    'demand': 101.51609116387452,
#    'sold': 101.51609,
#    'stored': 6.7395274,
#    'shortage': 0.0},
#   {'scenario': 333,
#    'demand': 86.45676576975777,
#    'sold': 86.456766,
#    'stored': 21.798853,
#    'shortage': 0.0},
#   {'scenario': 334,
#    'demand': 119.50239466835502,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 11.246776},
#   {'scenario': 335,
#    'demand': 97.05885236995722,
#    'sold': 97.058852,
#    'stored': 11.196766,
#    'shortage': 0.0},
#   {'scenario': 336,
#    'demand': 83.49005606414977,
#    'sold': 83.490056,
#    'stored': 24.765562,
#    'shortage': 0.0},
#   {'scenario': 337,
#    'demand': 93.57228316694014,
#    'sold': 93.572283,
#    'stored': 14.683335,
#    'shortage': 0.0},
#   {'scenario': 338,
#    'demand': 108.2586290855125,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 0.0030105468},
#   {'scenario': 339,
#    'demand': 88.7255089439205,
#    'sold': 88.725509,
#    'stored': 19.53011,
#    'shortage': 0.0},
#   {'scenario': 340,
#    'demand': 83.55559208867137,
#    'sold': 83.555592,
#    'stored': 24.700026,
#    'shortage': 0.0},
#   {'scenario': 341,
#    'demand': 104.87374422983825,
#    'sold': 104.87374,
#    'stored': 3.3818743,
#    'shortage': 0.0},
#   {'scenario': 342,
#    'demand': 104.89933142217446,
#    'sold': 104.89933,
#    'stored': 3.3562871,
#    'shortage': 0.0},
#   {'scenario': 343,
#    'demand': 89.8611364925774,
#    'sold': 89.861136,
#    'stored': 18.394482,
#    'shortage': 0.0},
#   {'scenario': 344,
#    'demand': 90.57923388763355,
#    'sold': 90.579234,
#    'stored': 17.676385,
#    'shortage': 0.0},
#   {'scenario': 345,
#    'demand': 104.64099874715272,
#    'sold': 104.641,
#    'stored': 3.6146198,
#    'shortage': 0.0},
#   {'scenario': 346,
#    'demand': 71.03831317005351,
#    'sold': 71.038313,
#    'stored': 37.217305,
#    'shortage': 0.0},
#   {'scenario': 347,
#    'demand': 71.8507245124689,
#    'sold': 71.850725,
#    'stored': 36.404894,
#    'shortage': 0.0},
#   {'scenario': 348,
#    'demand': 85.63111557495128,
#    'sold': 85.631116,
#    'stored': 22.624503,
#    'shortage': 0.0},
#   {'scenario': 349,
#    'demand': 95.73105696576306,
#    'sold': 95.731057,
#    'stored': 12.524562,
#    'shortage': 0.0},
#   {'scenario': 350,
#    'demand': 106.2181513119601,
#    'sold': 106.21815,
#    'stored': 2.0374672,
#    'shortage': 0.0},
#   {'scenario': 351,
#    'demand': 129.50712433899105,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 21.251506},
#   {'scenario': 352,
#    'demand': 117.15319246404039,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 8.8975739},
#   {'scenario': 353,
#    'demand': 96.80122940073146,
#    'sold': 96.801229,
#    'stored': 11.454389,
#    'shortage': 0.0},
#   {'scenario': 354,
#    'demand': 99.61967584194622,
#    'sold': 99.619676,
#    'stored': 8.6359427,
#    'shortage': 0.0},
#   {'scenario': 355,
#    'demand': 79.94941270724382,
#    'sold': 79.949413,
#    'stored': 28.306206,
#    'shortage': 0.0},
#   {'scenario': 356,
#    'demand': 99.6297372801522,
#    'sold': 99.629737,
#    'stored': 8.6258813,
#    'shortage': 0.0},
#   {'scenario': 357,
#    'demand': 94.22682722159725,
#    'sold': 94.226827,
#    'stored': 14.028791,
#    'shortage': 0.0},
#   {'scenario': 358,
#    'demand': 106.45437120676179,
#    'sold': 106.45437,
#    'stored': 1.8012473,
#    'shortage': 0.0},
#   {'scenario': 359,
#    'demand': 83.45538112895355,
#    'sold': 83.455381,
#    'stored': 24.800237,
#    'shortage': 0.0},
#   {'scenario': 360,
#    'demand': 110.38693028482345,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 2.1313117},
#   {'scenario': 361,
#    'demand': 130.65477826005156,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 22.39916},
#   {'scenario': 362,
#    'demand': 97.82479703086285,
#    'sold': 97.824797,
#    'stored': 10.430822,
#    'shortage': 0.0},
#   {'scenario': 363,
#    'demand': 108.03423444197882,
#    'sold': 108.03423,
#    'stored': 0.2213841,
#    'shortage': 0.0},
#   {'scenario': 364,
#    'demand': 113.80287983422225,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 5.5472613},
#   {'scenario': 365,
#    'demand': 91.97559056228327,
#    'sold': 91.975591,
#    'stored': 16.280028,
#    'shortage': 0.0},
#   {'scenario': 366,
#    'demand': 104.48184963620834,
#    'sold': 104.48185,
#    'stored': 3.7737689,
#    'shortage': 0.0},
#   {'scenario': 367,
#    'demand': 100.2518480156359,
#    'sold': 100.25185,
#    'stored': 8.0037705,
#    'shortage': 0.0},
#   {'scenario': 368,
#    'demand': 101.95352197097664,
#    'sold': 101.95352,
#    'stored': 6.3020966,
#    'shortage': 0.0},
#   {'scenario': 369,
#    'demand': 84.53980432289067,
#    'sold': 84.539804,
#    'stored': 23.715814,
#    'shortage': 0.0},
#   {'scenario': 370,
#    'demand': 100.49020348517885,
#    'sold': 100.4902,
#    'stored': 7.7654151,
#    'shortage': 0.0},
#   {'scenario': 371,
#    'demand': 109.95996582490899,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 1.7043473},
#   {'scenario': 372,
#    'demand': 129.02287215590084,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 20.767254},
#   {'scenario': 373,
#    'demand': 119.18541652170414,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 10.929798},
#   {'scenario': 374,
#    'demand': 143.06364915023113,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 34.808031},
#   {'scenario': 375,
#    'demand': 84.65304874223901,
#    'sold': 84.653049,
#    'stored': 23.60257,
#    'shortage': 0.0},
#   {'scenario': 376,
#    'demand': 117.44641273441357,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 9.1907942},
#   {'scenario': 377,
#    'demand': 103.66684011476704,
#    'sold': 103.66684,
#    'stored': 4.5887784,
#    'shortage': 0.0},
#   {'scenario': 378,
#    'demand': 143.79605866435344,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 35.54044},
#   {'scenario': 379,
#    'demand': 83.83403429289697,
#    'sold': 83.834034,
#    'stored': 24.421584,
#    'shortage': 0.0},
#   {'scenario': 380,
#    'demand': 83.20556315638447,
#    'sold': 83.205563,
#    'stored': 25.050055,
#    'shortage': 0.0},
#   {'scenario': 381,
#    'demand': 88.01214709111956,
#    'sold': 88.012147,
#    'stored': 20.243471,
#    'shortage': 0.0},
#   {'scenario': 382,
#    'demand': 57.52208551380386,
#    'sold': 57.522086,
#    'stored': 50.733533,
#    'shortage': 0.0},
#   {'scenario': 383,
#    'demand': 89.48489956638478,
#    'sold': 89.4849,
#    'stored': 18.770719,
#    'shortage': 0.0},
#   {'scenario': 384,
#    'demand': 84.81734676892604,
#    'sold': 84.817347,
#    'stored': 23.438272,
#    'shortage': 0.0},
#   {'scenario': 385,
#    'demand': 103.00787572952416,
#    'sold': 103.00788,
#    'stored': 5.2477428,
#    'shortage': 0.0},
#   {'scenario': 386,
#    'demand': 106.83511951554318,
#    'sold': 106.83512,
#    'stored': 1.420499,
#    'shortage': 0.0},
#   {'scenario': 387,
#    'demand': 137.52341678431773,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 29.267798},
#   {'scenario': 388,
#    'demand': 119.008476763721,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 10.752858},
#   {'scenario': 389,
#    'demand': 88.46192688675194,
#    'sold': 88.461927,
#    'stored': 19.793692,
#    'shortage': 0.0},
#   {'scenario': 390,
#    'demand': 82.03170657303284,
#    'sold': 82.031707,
#    'stored': 26.223912,
#    'shortage': 0.0},
#   {'scenario': 391,
#    'demand': 109.83838343013011,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 1.5827649},
#   {'scenario': 392,
#    'demand': 73.59533585958715,
#    'sold': 73.595336,
#    'stored': 34.660283,
#    'shortage': 0.0},
#   {'scenario': 393,
#    'demand': 136.62917531708706,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 28.373557},
#   {'scenario': 394,
#    'demand': 123.58880241442574,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 15.333184},
#   {'scenario': 395,
#    'demand': 90.6164869579059,
#    'sold': 90.616487,
#    'stored': 17.639132,
#    'shortage': 0.0},
#   {'scenario': 396,
#    'demand': 65.73730941818243,
#    'sold': 65.737309,
#    'stored': 42.518309,
#    'shortage': 0.0},
#   {'scenario': 397,
#    'demand': 127.07744748330826,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 18.821829},
#   {'scenario': 398,
#    'demand': 97.70920309494764,
#    'sold': 97.709203,
#    'stored': 10.546415,
#    'shortage': 0.0},
#   {'scenario': 399,
#    'demand': 124.75632623946923,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 16.500708},
#   {'scenario': 400,
#    'demand': 68.11144682411266,
#    'sold': 68.111447,
#    'stored': 40.144172,
#    'shortage': 0.0},
#   {'scenario': 401,
#    'demand': 88.01249954092454,
#    'sold': 88.0125,
#    'stored': 20.243119,
#    'shortage': 0.0},
#   {'scenario': 402,
#    'demand': 100.10487399436366,
#    'sold': 100.10487,
#    'stored': 8.1507445,
#    'shortage': 0.0},
#   {'scenario': 403,
#    'demand': 100.93961187529484,
#    'sold': 100.93961,
#    'stored': 7.3160067,
#    'shortage': 0.0},
#   {'scenario': 404,
#    'demand': 90.99869057041512,
#    'sold': 90.998691,
#    'stored': 17.256928,
#    'shortage': 0.0},
#   {'scenario': 405,
#    'demand': 112.45699864694997,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 4.2013801},
#   {'scenario': 406,
#    'demand': 78.6475914123481,
#    'sold': 78.647591,
#    'stored': 29.608027,
#    'shortage': 0.0},
#   {'scenario': 407,
#    'demand': 97.15241029957413,
#    'sold': 97.15241,
#    'stored': 11.103208,
#    'shortage': 0.0},
#   {'scenario': 408,
#    'demand': 102.40591263423798,
#    'sold': 102.40591,
#    'stored': 5.8497059,
#    'shortage': 0.0},
#   {'scenario': 409,
#    'demand': 110.28877668117498,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 2.0331581},
#   {'scenario': 410,
#    'demand': 114.23229756177778,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 5.976679},
#   {'scenario': 411,
#    'demand': 77.50715816324262,
#    'sold': 77.507158,
#    'stored': 30.74846,
#    'shortage': 0.0},
#   {'scenario': 412,
#    'demand': 69.31771658528756,
#    'sold': 69.317717,
#    'stored': 38.937902,
#    'shortage': 0.0},
#   {'scenario': 413,
#    'demand': 125.55353643797018,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 17.297918},
#   {'scenario': 414,
#    'demand': 106.64628023959183,
#    'sold': 106.64628,
#    'stored': 1.6093383,
#    'shortage': 0.0},
#   {'scenario': 415,
#    'demand': 85.03026926886892,
#    'sold': 85.030269,
#    'stored': 23.225349,
#    'shortage': 0.0},
#   {'scenario': 416,
#    'demand': 131.02303951045047,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 22.767421},
#   {'scenario': 417,
#    'demand': 102.31349268585717,
#    'sold': 102.31349,
#    'stored': 5.9421259,
#    'shortage': 0.0},
#   {'scenario': 418,
#    'demand': 123.58594368127653,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 15.330325},
#   {'scenario': 419,
#    'demand': 101.35036962820217,
#    'sold': 101.35037,
#    'stored': 6.9052489,
#    'shortage': 0.0},
#   {'scenario': 420,
#    'demand': 141.21495849763974,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 32.95934},
#   {'scenario': 421,
#    'demand': 135.10681684886407,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 26.851198},
#   {'scenario': 422,
#    'demand': 95.02071703041852,
#    'sold': 95.020717,
#    'stored': 13.234902,
#    'shortage': 0.0},
#   {'scenario': 423,
#    'demand': 119.43141901908712,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 11.1758},
#   {'scenario': 424,
#    'demand': 112.90751899170294,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 4.6519005},
#   {'scenario': 425,
#    'demand': 127.37263115064698,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 19.117013},
#   {'scenario': 426,
#    'demand': 80.70153078839792,
#    'sold': 80.701531,
#    'stored': 27.554088,
#    'shortage': 0.0},
#   {'scenario': 427,
#    'demand': 113.72102919996878,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 5.4654107},
#   {'scenario': 428,
#    'demand': 121.16848973699176,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 12.912871},
#   {'scenario': 429,
#    'demand': 64.82521027153771,
#    'sold': 64.82521,
#    'stored': 43.430408,
#    'shortage': 0.0},
#   {'scenario': 430,
#    'demand': 76.3348297466845,
#    'sold': 76.33483,
#    'stored': 31.920789,
#    'shortage': 0.0},
#   {'scenario': 431,
#    'demand': 59.21535644479799,
#    'sold': 59.215356,
#    'stored': 49.040262,
#    'shortage': 0.0},
#   {'scenario': 432,
#    'demand': 94.61186331110885,
#    'sold': 94.611863,
#    'stored': 13.643755,
#    'shortage': 0.0},
#   {'scenario': 433,
#    'demand': 114.35084511591924,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 6.0952266},
#   {'scenario': 434,
#    'demand': 130.04714104192055,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 21.791523},
#   {'scenario': 435,
#    'demand': 101.4818956083955,
#    'sold': 101.4819,
#    'stored': 6.7737229,
#    'shortage': 0.0},
#   {'scenario': 436,
#    'demand': 132.57231091142583,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 24.316692},
#   {'scenario': 437,
#    'demand': 72.39797083570217,
#    'sold': 72.397971,
#    'stored': 35.857648,
#    'shortage': 0.0},
#   {'scenario': 438,
#    'demand': 65.9323512128969,
#    'sold': 65.932351,
#    'stored': 42.323267,
#    'shortage': 0.0},
#   {'scenario': 439,
#    'demand': 98.88904602206762,
#    'sold': 98.889046,
#    'stored': 9.3665725,
#    'shortage': 0.0},
#   {'scenario': 440,
#    'demand': 107.68130897878615,
#    'sold': 107.68131,
#    'stored': 0.57430956,
#    'shortage': 0.0},
#   {'scenario': 441,
#    'demand': 99.34610503811814,
#    'sold': 99.346105,
#    'stored': 8.9095135,
#    'shortage': 0.0},
#   {'scenario': 442,
#    'demand': 58.65115799920247,
#    'sold': 58.651158,
#    'stored': 49.604461,
#    'shortage': 0.0},
#   {'scenario': 443,
#    'demand': 98.21759920974424,
#    'sold': 98.217599,
#    'stored': 10.038019,
#    'shortage': 0.0},
#   {'scenario': 444,
#    'demand': 73.91060998990294,
#    'sold': 73.91061,
#    'stored': 34.345009,
#    'shortage': 0.0},
#   {'scenario': 445,
#    'demand': 113.39345097660077,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 5.1378324},
#   {'scenario': 446,
#    'demand': 107.33196492193696,
#    'sold': 107.33196,
#    'stored': 0.92365362,
#    'shortage': 0.0},
#   {'scenario': 447,
#    'demand': 81.2024042734529,
#    'sold': 81.202404,
#    'stored': 27.053214,
#    'shortage': 0.0},
#   {'scenario': 448,
#    'demand': 89.72266165326613,
#    'sold': 89.722662,
#    'stored': 18.532957,
#    'shortage': 0.0},
#   {'scenario': 449,
#    'demand': 78.81572956222097,
#    'sold': 78.81573,
#    'stored': 29.439889,
#    'shortage': 0.0},
#   {'scenario': 450,
#    'demand': 98.74641805453656,
#    'sold': 98.746418,
#    'stored': 9.5092005,
#    'shortage': 0.0},
#   {'scenario': 451,
#    'demand': 119.10284641002477,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 10.847228},
#   {'scenario': 452,
#    'demand': 80.28547907328912,
#    'sold': 80.285479,
#    'stored': 27.970139,
#    'shortage': 0.0},
#   {'scenario': 453,
#    'demand': 110.08093031035689,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 1.8253118},
#   {'scenario': 454,
#    'demand': 89.39484763255118,
#    'sold': 89.394848,
#    'stored': 18.860771,
#    'shortage': 0.0},
#   {'scenario': 455,
#    'demand': 84.14254335475312,
#    'sold': 84.142543,
#    'stored': 24.113075,
#    'shortage': 0.0},
#   {'scenario': 456,
#    'demand': 97.85939280090885,
#    'sold': 97.859393,
#    'stored': 10.396226,
#    'shortage': 0.0},
#   {'scenario': 457,
#    'demand': 79.29515355161251,
#    'sold': 79.295154,
#    'stored': 28.960465,
#    'shortage': 0.0},
#   {'scenario': 458,
#    'demand': 88.92701389305635,
#    'sold': 88.927014,
#    'stored': 19.328605,
#    'shortage': 0.0},
#   {'scenario': 459,
#    'demand': 76.04244214822303,
#    'sold': 76.042442,
#    'stored': 32.213176,
#    'shortage': 0.0},
#   {'scenario': 460,
#    'demand': 139.2945026583278,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 31.038884},
#   {'scenario': 461,
#    'demand': 100.70527103943458,
#    'sold': 100.70527,
#    'stored': 7.5503475,
#    'shortage': 0.0},
#   {'scenario': 462,
#    'demand': 86.0054898401483,
#    'sold': 86.00549,
#    'stored': 22.250129,
#    'shortage': 0.0},
#   {'scenario': 463,
#    'demand': 104.27959821468444,
#    'sold': 104.2796,
#    'stored': 3.9760203,
#    'shortage': 0.0},
#   {'scenario': 464,
#    'demand': 97.75343900618341,
#    'sold': 97.753439,
#    'stored': 10.50218,
#    'shortage': 0.0},
#   {'scenario': 465,
#    'demand': 95.58060800933555,
#    'sold': 95.580608,
#    'stored': 12.675011,
#    'shortage': 0.0},
#   {'scenario': 466,
#    'demand': 112.2833340008685,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 4.0277155},
#   {'scenario': 467,
#    'demand': 115.1501542009461,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 6.8945357},
#   {'scenario': 468,
#    'demand': 89.38997704778944,
#    'sold': 89.389977,
#    'stored': 18.865641,
#    'shortage': 0.0},
#   {'scenario': 469,
#    'demand': 88.4836351871064,
#    'sold': 88.483635,
#    'stored': 19.771983,
#    'shortage': 0.0},
#   {'scenario': 470,
#    'demand': 94.49896605696712,
#    'sold': 94.498966,
#    'stored': 13.756652,
#    'shortage': 0.0},
#   {'scenario': 471,
#    'demand': 53.9615767052883,
#    'sold': 53.961577,
#    'stored': 54.294042,
#    'shortage': 0.0},
#   {'scenario': 472,
#    'demand': 69.69617875602896,
#    'sold': 69.696179,
#    'stored': 38.55944,
#    'shortage': 0.0},
#   {'scenario': 473,
#    'demand': 127.33748534889048,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 19.081867},
#   {'scenario': 474,
#    'demand': 132.89935427002567,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 24.643736},
#   {'scenario': 475,
#    'demand': 95.01927920887243,
#    'sold': 95.019279,
#    'stored': 13.236339,
#    'shortage': 0.0},
#   {'scenario': 476,
#    'demand': 111.53113926111533,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 3.2755207},
#   {'scenario': 477,
#    'demand': 106.22500309087073,
#    'sold': 106.225,
#    'stored': 2.0306154,
#    'shortage': 0.0},
#   {'scenario': 478,
#    'demand': 161.57761616910477,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 53.321998},
#   {'scenario': 479,
#    'demand': 122.39149822869153,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 14.13588},
#   {'scenario': 480,
#    'demand': 97.44164817038467,
#    'sold': 97.441648,
#    'stored': 10.81397,
#    'shortage': 0.0},
#   {'scenario': 481,
#    'demand': 80.88919118799149,
#    'sold': 80.889191,
#    'stored': 27.366427,
#    'shortage': 0.0},
#   {'scenario': 482,
#    'demand': 67.87107359484855,
#    'sold': 67.871074,
#    'stored': 40.384545,
#    'shortage': 0.0},
#   {'scenario': 483,
#    'demand': 104.06927271734446,
#    'sold': 104.06927,
#    'stored': 4.1863458,
#    'shortage': 0.0},
#   {'scenario': 484,
#    'demand': 84.87298509431393,
#    'sold': 84.872985,
#    'stored': 23.382633,
#    'shortage': 0.0},
#   {'scenario': 485,
#    'demand': 71.55492580804652,
#    'sold': 71.554926,
#    'stored': 36.700693,
#    'shortage': 0.0},
#   {'scenario': 486,
#    'demand': 87.06854231514947,
#    'sold': 87.068542,
#    'stored': 21.187076,
#    'shortage': 0.0},
#   {'scenario': 487,
#    'demand': 78.3690399277121,
#    'sold': 78.36904,
#    'stored': 29.886579,
#    'shortage': 0.0},
#   {'scenario': 488,
#    'demand': 133.74283270145128,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 25.487214},
#   {'scenario': 489,
#    'demand': 117.63279513898901,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 9.3771766},
#   {'scenario': 490,
#    'demand': 99.84054717366766,
#    'sold': 99.840547,
#    'stored': 8.4150714,
#    'shortage': 0.0},
#   {'scenario': 491,
#    'demand': 129.59888277780053,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 21.343264},
#   {'scenario': 492,
#    'demand': 101.54736615295236,
#    'sold': 101.54737,
#    'stored': 6.7082524,
#    'shortage': 0.0},
#   {'scenario': 493,
#    'demand': 82.77431597343472,
#    'sold': 82.774316,
#    'stored': 25.481303,
#    'shortage': 0.0},
#   {'scenario': 494,
#    'demand': 130.46248154539313,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 22.206863},
#   {'scenario': 495,
#    'demand': 110.77820087369318,
#    'sold': 108.25562,
#    'stored': 0.0,
#    'shortage': 2.5225823},
#   {'scenario': 496,
#    'demand': 79.25507691347087,
#    'sold': 79.255077,
#    'stored': 29.000542,
#    'shortage': 0.0},
#   {'scenario': 497,
#    'demand': 96.19322643832784,
#    'sold': 96.193226,
#    'stored': 12.062392,
#    'shortage': 0.0},
#   {'scenario': 498,
#    'demand': 82.48763493230484,
#    'sold': 82.487635,
#    'stored': 25.767984,
#    'shortage': 0.0},
#   {'scenario': 499,
#    'demand': 72.34400538071327,
#    'sold': 72.344005,
#    'stored': 35.911613,
#    'shortage': 0.0}]}

# %%
import pyomo.environ as pyo
solvers = pyo.SolverFactory.__dict__['_cls'].keys()
print("Available solvers:", list(solvers))
# Out:
# Available solvers: ['_neos', 'cbc', '_cbc_shell', '_mock_cbc', 'glpk', '_glpk_shell', '_mock_glpk', 'cplex', '_cplex_shell', '_mock_cplex', 'gurobi_direct', 'asl', '_mock_asl', 'gurobi', '_gurobi_nl', '_gurobi_shell', '_gurobi_file', 'baron', 'py', 'scip', 'conopt', 'xpress', 'ipopt', 'gurobi_persistent', 'cplex_direct', 'cplex_persistent', 'gams', '_gams_direct', '_gams_shell', 'mosek', 'mosek_direct', 'mosek_persistent', 'xpress_direct', 'xpress_persistent', 'sas', '_sas94', '_sascas', 'cp_optimizer', 'mpec_nlp', 'mpec_minlp', 'path', 'appsi_gurobi', 'appsi_cplex', 'appsi_ipopt', 'appsi_cbc', 'appsi_highs', 'appsi_maingo', 'gdpopt', 'gdpopt.gloa', 'gdpopt.lbb', 'gdpopt.loa', 'gdpopt.ric', 'gdpopt.enumerate', 'gdpopt.ldsda', 'contrib.gjh', 'mindtpy', 'mindtpy.oa', 'mindtpy.ecp', 'mindtpy.goa', 'mindtpy.fp', 'multistart', 'cyipopt', 'scipy.fsolve', 'scipy.root', 'scipy.newton', 'scipy.secant-newton', 'ipopt_v2', 'gurobi_v2', 'gurobi_direct_v2', 'trustregion']
